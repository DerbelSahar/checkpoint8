# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

       	['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

       	['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

       	['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

      ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
# %matplotlib inline
import numpy as np
import pandas as pd 
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)
df=pd.DataFrame(te_ary,columns=te.columns_)
df
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %%
from mlxtend.frequent_patterns import apriori
frequent_itemsets=apriori(df,use_colnames=True)
frequent_itemsets
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Scarf, Pants)
# 5      0.6  (Skirt, Pants)

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.75)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0         1.0  1.25      0.12         inf

# %%
data
# Out:
#                  shrimp            almonds            avocado  \
# 0               burgers          meatballs               eggs
# 1               chutney                NaN                NaN
# 2                turkey            avocado                NaN
# 3         mineral water               milk         energy bar
# 4        low fat yogurt                NaN                NaN
# 5     whole wheat pasta       french fries                NaN
# 6                  soup        light cream            shallot
# 7     frozen vegetables          spaghetti          green tea
# 8          french fries                NaN                NaN
# 9                  eggs           pet food                NaN
# 10              cookies                NaN                NaN
# 11               turkey            burgers      mineral water
# 12            spaghetti          champagne            cookies
# 13        mineral water             salmon                NaN
# ...

# %%
data=pd.read_csv("D:GL/formations/gomycode/Market_Basket_Optimisation.csv",header=None)

# %%
data.shape
# Out:
# (7501, 20)

# %%
items=[]
for i in range(0,7501):
    items.append([str(data.values[i,j]) for j in range(0,20)])

# %%
from apyori import apriori
final_rule=apriori(items,use_columns=True)
final_results=list(final_rule)
result=pd.DataFrame(final_results)
result
# Out:
#                    items   support  \
# 0            (chocolate)  0.163845
# 1                 (eggs)  0.179709
# 2         (french fries)  0.170911
# 3            (green tea)  0.132116
# 4                 (milk)  0.129583
# 5        (mineral water)  0.238368
# 6                  (nan)  0.999867
# 7            (spaghetti)  0.174110
# 8       (chocolate, nan)  0.163845
# 9            (nan, eggs)  0.179709
# 10   (nan, french fries)  0.170911
# 11      (nan, green tea)  0.131982
# 12           (nan, milk)  0.129583
# 13  (nan, mineral water)  0.238235
# 14      (nan, spaghetti)  0.174110
#
#                                    ordered_statistics
# 0        [((), (chocolate), 0.1638448206905746, 1.0)]
# 1            [((), (eggs), 0.17970937208372217, 1.0)]
# 2     [((), (french fries), 0.1709105452606319, 1.0)]
# 3       [((), (green tea), 0.13211571790427942, 1.0)]
# 4            [((), (milk), 0.12958272230369283, 1.0)]
# 5   [((), (mineral water), 0.23836821757099053, 1.0)]
# ...
